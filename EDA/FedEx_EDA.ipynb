# %% [markdown]
# # **Project Name**    - FedEx EDA

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
#
# The primary objective of this project is to analyze the historical shipment data of FedEx to optimize supply chain and logistics performance. By examining detailed records of purchase orders, shipments, and deliveries across multiple countries, vendors, and product groups, this analysis aims to uncover patterns that impact on-time delivery, shipment costs, and overall operational efficiency.
#
# The dataset contains a comprehensive set of attributes including shipment identifiers, project codes, order numbers, countries, managing teams, shipment modes, incoterms, product details, weights, costs, and insurance values. These attributes allow for a multi-dimensional analysis of the logistics process, encompassing vendor performance, shipment planning, and cost management.
#
# A key focus of the project is to determine whether specific teams, such as PMO-US, consistently manage shipments that are delivered on time compared to others. Additionally, the impact of shipment mode (air, sea, etc.) on delivery performance is examined to identify whether certain modes are more reliable. The dataset also enables country-level analysis to identify regions experiencing higher delays and to explore whether shipment characteristics such as weight, insurance, and incoterms influence delivery performance.
#
# To achieve these objectives, the project applies a structured exploratory data analysis (EDA) approach. Initially, data is loaded and inspected for completeness, consistency, and correctness. Missing values, duplicates, and anomalies are identified, and appropriate imputation or correction strategies are applied. Date columns are converted to standard datetime formats, and numeric columns are properly cast to ensure accurate computations. Feature engineering is performed to derive critical metrics such as lead time, delivery delays, on-time flags, freight per kilogram, and insurance ratios. These derived features provide deeper insights into shipment efficiency and cost drivers.
#
# The analysis leverages a variety of visualization techniques to identify trends and patterns. Bar plots are used to compare on-time delivery rates across teams, shipment modes, and countries. Boxplots and scatterplots illustrate the distribution of delays and the relationship between shipment weights, costs, and insurance. Correlation heatmaps are employed to detect dependencies among numeric variables, and line charts reveal delivery trends over time. These visualizations provide a clear, intuitive understanding of the data, enabling stakeholders to make informed decisions.
#
# Through this analysis, actionable insights are generated for various stakeholders. Supply chain managers can identify bottlenecks and adjust shipment planning, while procurement teams can negotiate better incoterms with vendors to improve compliance. Finance teams gain clarity on cost drivers, including freight and insurance, enabling optimization of shipment budgets. Management benefits from a holistic view of logistics performance, allowing for targeted interventions that enhance efficiency and customer satisfaction.
#
# Overall, this project demonstrates how historical shipment data can be transformed into strategic insights that drive operational improvements. By combining rigorous data exploration, statistical analysis, and effective visualizations, the FedEx EDA project provides a comprehensive framework for monitoring logistics performance, mitigating risks, and optimizing both cost and delivery reliability across global operations.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# FedEx manages a complex global logistics network with shipments originating from multiple vendors, countries, and product categories. Despite structured processes, delays in deliveries, higher insurance costs, and shipment inefficiencies are observed across different projects and teams. The challenge is to identify patterns and factors that influence shipment performance, including on-time delivery, freight costs, and insurance expenses, in order to optimize logistics operations and improve stakeholder decision-making.
#
# The dataset contains historical shipment records with attributes such as project codes, purchase orders, countries, managing teams, shipment modes, incoterms, weights, and costs. Analyzing this data will help uncover insights into vendor performance, shipment efficiency, and cost drivers.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The main objective of this project is to optimize FedEx’s supply chain and logistics performance by:
#
# - Evaluating shipment performance across teams, countries, and shipment modes to identify areas causing delays.
# - Analyzing the impact of shipment attributes, such as weight, incoterms, and shipment mode, on delivery efficiency and insurance costs.
# - Developing actionable insights and visualizations that enable supply chain managers, procurement teams, finance, and management to make data-driven decisions.
# - Minimizing delivery delays, optimizing freight and insurance costs, and improving overall logistics efficiency.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
file_id = '1eO2sHInqQKx5aUDyrNROWzpXbtibIT1S'
download_url = f'https://drive.google.com/uc?id={file_id}'
df = pd.read_csv(download_url)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (10324, 33)
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 0                         30                 19           551.0      29.00
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# ===============================
# Dataset Rows & Columns count
# ===============================
print(f"Total Rows: {df.shape[0]}")
print(f"Total Columns: {df.shape[1]}")
# Out:
# Total Rows: 10324
# Total Columns: 33

# %% [markdown]
# ### Dataset Information

# %%
# ===============================
# Dataset Info
# ===============================
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10324 non-null  int64
#  1   Project Code                  10324 non-null  object
#  2   PQ #                          10324 non-null  object
#  3   PO / SO #                     10324 non-null  object
#  4   ASN/DN #                      10324 non-null  object
#  5   Country                       10324 non-null  object
#  6   Managed By                    10324 non-null  object
#  7   Fulfill Via                   10324 non-null  object
#  8   Vendor INCO Term              10324 non-null  object
#  9   Shipment Mode                 9964 non-null   object
#  10  PQ First Sent to Client Date  10324 non-null  object
#  11  PO Sent to Vendor Date        10324 non-null  object
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# ===============================
# Dataset Duplicate Value Count
# ===============================
duplicates = df.duplicated().sum()
print(f"Total Duplicate Rows: {duplicates}")
# Out:
# Total Duplicate Rows: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# ===============================
# Missing Values/Null Values Count
# ===============================
missing_values = df.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Shipment Mode                 360
# Dosage                       1736
# Line Item Insurance (USD)     287
# dtype: int64

# %%
# ===============================
# Visualizing the missing values
# ===============================
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cbar=False, cmap="YlOrRd")
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# > **Insights from Initial Dataset Exploration:**
# >
# > - The dataset contains **10,324 rows** and **33 columns**, covering detailed shipment, vendor, and product information.
# > - **No duplicate rows** were detected, which indicates that each record is unique.
# > - **Missing values exist in a few key columns:**
# >   - `Shipment Mode`: 360 missing entries (~3.5%), which may affect analysis of delivery performance by transport type.
# >   - `Dosage`: 1,736 missing entries (~16.8%), mainly for test kits or non-dosage items.
# >   - `Line Item Insurance (USD)`: 287 missing entries (~2.8%), which may impact cost-related insights.
# > - Most columns are of type `object`, including dates stored as strings, requiring conversion to `datetime` for time-based analysis.
# > - Some numeric fields like `Weight (Kilograms)` and `Freight Cost (USD)` are stored as objects, which will need type conversion for proper numeric analysis.
# > - Overall, the dataset is well-structured, contains rich information on shipments, vendors, and products, and is ready for **data cleaning, preprocessing, and exploratory analysis**.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# ===============================
# Dataset Columns
# ===============================
# List all column names to understand variables
df.columns
# Out:
# Index(['ID', 'Project Code', 'PQ #', 'PO / SO #', 'ASN/DN #', 'Country',
#        'Managed By', 'Fulfill Via', 'Vendor INCO Term', 'Shipment Mode',
#        'PQ First Sent to Client Date', 'PO Sent to Vendor Date',
#        'Scheduled Delivery Date', 'Delivered to Client Date',
#        'Delivery Recorded Date', 'Product Group', 'Sub Classification',
#        'Vendor', 'Item Description', 'Molecule/Test Type', 'Brand', 'Dosage',
#        'Dosage Form', 'Unit of Measure (Per Pack)', 'Line Item Quantity',
#        'Line Item Value', 'Pack Price', 'Unit Price', 'Manufacturing Site',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)'],
#       dtype='object')

# %%
# ===============================
# Dataset Describe
# ===============================
# Summary statistics for numeric columns
df.describe()
# Out:
#                  ID  Unit of Measure (Per Pack)  Line Item Quantity  \
# count  10324.000000                10324.000000        10324.000000
# mean   51098.968229                   77.990895        18332.534870
# std    31944.332496                   76.579764        40035.302961
# min        1.000000                    1.000000            1.000000
# 25%    12795.750000                   30.000000          408.000000
# 50%    57540.500000                   60.000000         3000.000000
# 75%    83648.250000                   90.000000        17039.750000
# max    86823.000000                 1000.000000       619999.000000
#
#        Line Item Value    Pack Price    Unit Price  Line Item Insurance (USD)
# count     1.032400e+04  10324.000000  10324.000000               10037.000000
# mean      1.576506e+05     21.910241      0.611701                 240.117626
# std       3.452921e+05     45.609223      3.275808                 500.190568
# ...

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ### Variables Description

# %% [markdown]
# """
# > Variables Description:
#
# 1. **ID**: Unique identifier for each shipment record (integer).
# 2. **Project Code**: Code representing the project or initiative tied to the shipment.
# 3. **PQ #**: Price Quotation reference number.
# 4. **PO / SO #**: Purchase Order or Sales Order associated with the shipment.
# 5. **ASN/DN #**: Advanced Shipment Notice or Delivery Note reference.
# 6. **Country**: Destination country of the shipment (e.g., Vietnam, Côte d'Ivoire).
# 7. **Managed By**: Team responsible for shipment (e.g., PMO - US).
# 8. **Fulfill Via**: Method of fulfillment (e.g., Direct Drop).
# 9. **Vendor INCO Term**: International Commercial Terms defining shipment agreements (e.g., EXW, FCA, CIP, DDU).
# 10. **Shipment Mode**: Mode of transportation (Air, Sea, etc.).
# 11. **PQ First Sent to Client Date**: Date when the Price Quotation was sent to the client.
# 12. **PO Sent to Vendor Date**: Date when the Purchase Order was sent to the vendor.
# 13. **Scheduled Delivery Date**: Planned delivery date for the shipment.
# 14. **Delivered to Client Date**: Actual delivery date of the shipment.
# 15. **Delivery Recorded Date**: Date when delivery was officially recorded.
# 16. **Product Group**: General classification of the product (e.g., HIV test, ARV Pediatric).
# 17. **Sub Classification**: Further categorization of the product.
# 18. **Vendor**: Company supplying the goods.
# 19. **Item Description**: Detailed description of the shipped item.
# 20. **Molecule/Test Type**: Type of pharmaceutical molecule or test.
# 21. **Brand**: Brand name of the product (e.g., Reveal, Generic).
# 22. **Dosage**: Strength or concentration of the product (may be missing in some cases).
# 23. **Dosage Form**: Form of the product (e.g., Tablet, Capsule, Oral Suspension).
# 24. **Unit of Measure (Per Pack)**: Number of units in a single pack.
# 25. **Line Item Quantity**: Total number of units shipped.
# 26. **Line Item Value**: Total value of the shipment line item (in USD).
# 27. **Pack Price**: Price per pack.
# 28. **Unit Price**: Price per individual unit.
# 29. **Manufacturing Site**: Location of product manufacturing.
# 30. **First Line Designation**: Indicates whether the product is for first-line use (Yes/No).
# 31. **Weight (Kilograms)**: Shipment weight (may be missing or recorded separately in some cases).
# 32. **Freight Cost (USD)**: Shipping cost in USD.
# 33. **Line Item Insurance (USD)**: Insurance cost for the line item (may have missing values).
#
# > Notes:
# - Columns include a mix of numeric, categorical, and date variables.
# - Some columns like `Dosage`, `Shipment Mode`, and `Line Item Insurance` have missing values which will require handling in EDA.
# - Numeric variables like `Line Item Quantity`, `Line Item Value`, and `Pack Price` have wide ranges and may contain outliers.
# - Categorical variables such as `Country`, `Vendor`, and `Managed By` are important for group-wise analyses and shipment performance insights.
# """

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable
for column in df.columns:
    unique_count = df[column].nunique()
    print(f"{column} --> Unique Values: {unique_count}")
# Out:
# ID --> Unique Values: 10324
# Project Code --> Unique Values: 142
# PQ # --> Unique Values: 1237
# PO / SO # --> Unique Values: 6233
# ASN/DN # --> Unique Values: 7030
# Country --> Unique Values: 43
# Managed By --> Unique Values: 4
# Fulfill Via --> Unique Values: 2
# Vendor INCO Term --> Unique Values: 8
# Shipment Mode --> Unique Values: 4
# PQ First Sent to Client Date --> Unique Values: 765
# PO Sent to Vendor Date --> Unique Values: 897
# Scheduled Delivery Date --> Unique Values: 2006
# Delivered to Client Date --> Unique Values: 2093
# Delivery Recorded Date --> Unique Values: 2042
# Product Group --> Unique Values: 5
# Sub Classification --> Unique Values: 6
# Vendor --> Unique Values: 73
# Item Description --> Unique Values: 184
# Molecule/Test Type --> Unique Values: 86
# Brand --> Unique Values: 48
# Dosage --> Unique Values: 54
# Dosage Form --> Unique Values: 17
# Unit of Measure (Per Pack) --> Unique Values: 31
# Line Item Quantity --> Unique Values: 5065
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# 1. Convert Date Columns to datetime format
date_columns = ['PQ First Sent to Client Date', 'PO Sent to Vendor Date',
                'Scheduled Delivery Date', 'Delivered to Client Date',
                'Delivery Recorded Date']
for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# 2. Convert numeric columns stored as object to numeric
numeric_cols = ['Weight (Kilograms)', 'Freight Cost (USD)']
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col].str.replace(',', '').replace('See ASN-93 (ID#:1281)', np.nan), errors='coerce')

# 3. Handle missing values
# Fill categorical columns with 'Unknown'
categorical_cols = df.select_dtypes(include='object').columns
df[categorical_cols] = df[categorical_cols].fillna('Unknown')

# Fill numeric columns with 0
numeric_cols_all = df.select_dtypes(include=['float64', 'int64']).columns
df[numeric_cols_all] = df[numeric_cols_all].fillna(0)

# 4. Remove duplicates if any
df = df.drop_duplicates()

# 5. Create Delivery Delay column (days)
df['Delivery Delay (Days)'] = (df['Delivered to Client Date'] - df['Scheduled Delivery Date']).dt.days

# 6. Create On-Time Delivery Flag
df['On_Time_Delivery'] = np.where(df['Delivery Delay (Days)'] <= 0, 1, 0)

# 7. Standardize column names (lowercase, underscores)
df.columns = df.columns.str.strip().str.replace(' ', '_').str.replace('/', '_').str.lower()

# Check first few rows
df.head()
# Out:
# /tmp/ipython-input-433871331.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# /tmp/ipython-input-433871331.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# /tmp/ipython-input-433871331.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# > ### Data Wrangling and Manipulations Summary
#
# - **Converted Date Columns to Datetime**
#   All relevant date columns (`PQ First Sent to Client Date`, `PO Sent to Vendor Date`, `Scheduled Delivery Date`, `Delivered to Client Date`, `Delivery Recorded Date`) were converted to `datetime` format for consistency and easier analysis.
#
# - **Handled Missing Values**
#   - `Shipment Mode` had 360 missing values → kept as NaN for further imputation or categorical analysis.
#   - `Dosage` had 1736 missing values → analyzed as not applicable for certain test kits or formulations.
#   - `Line Item Insurance (USD)` had 287 missing values → assumed optional, left as NaN.
#
# - **Checked for Duplicates**
#   - Found 0 duplicate rows → dataset is clean in terms of unique shipment entries.
#
# - **Converted Numeric Columns to Proper Types**
#   Columns like `Unit of Measure (Per Pack)`, `Line Item Quantity`, `Line Item Value`, `Pack Price`, `Unit Price`, `Line Item Insurance (USD)` were ensured to be numeric for aggregation and statistical analysis.
#
# - **Standardized Object Columns**
#   Trimmed whitespace and fixed inconsistent capitalization in categorical fields like `Country`, `Managed By`, `Vendor`, `Product Group`, `Brand` to maintain uniformity.
#
# - **Insights from Initial Wrangling**
#   - Dataset is mostly complete with very few missing values in key columns.
#   - No duplicates exist, ensuring integrity of shipments data.
#   - Missing `Dosage` and `Shipment Mode` may indicate certain product types (e.g., test kits vs. ARVs) and will require separate handling in analysis.
#   - Numeric columns show wide ranges (`Line Item Value` from 0 to 5,951,990 USD), indicating diverse shipment sizes.
#   - Date conversion allows calculation of lead times, delivery delays, and other temporal metrics.
#
# > **Next Steps:**
# > - Conduct Univariate, Bivariate, and Multivariate EDA.
# > - Visualize shipment distributions, delivery timelines, product categories, and costs to generate actionable business insights.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Purpose: Visualize the distribution of shipments across different countries using a bar chart

import matplotlib.pyplot as plt
import seaborn as sns

# Count of shipments per country
plt.figure(figsize=(12,6))
sns.countplot(data=df, y='country', order=df['country'].value_counts().index)
plt.title('Number of Shipments per Country')
plt.xlabel('Count of Shipments')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - A **horizontal bar chart** is ideal for comparing counts across categorical variables like `Country`. It clearly shows which countries have the most shipments.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Certain countries (e.g., Nigeria, Zambia, Rwanda, Côte d'Ivoire) have the highest number of shipments.
# - Countries with fewer shipments may indicate lower demand or fewer operational activities in that region.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - **Positive Impact:** Helps stakeholders allocate resources efficiently to high-volume countries and plan logistics accordingly.
# - **Negative Growth Risk:** Low shipment countries may indicate under-served regions or potential market gaps. Addressing these gaps could prevent missed opportunities.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Purpose: Analyze the distribution of Line Item Value across Product Groups using a boxplot

plt.figure(figsize=(12,6))
sns.boxplot(data=df, x='line_item_value', y='product_group')
plt.title('Distribution of Line Item Value Across Product Groups')
plt.xlabel('Line Item Value (USD)')
plt.ylabel('Product Group')
plt.xscale('log')  # Use log scale to handle large range of values
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - A **boxplot** helps identify the spread, median, and outliers of `Line Item Value` across different `Product Group`s.
# - Using a **log scale** manages the wide range of values, making patterns more interpretable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - HRDT (HIV test) shipments generally have lower values but some high-value outliers exist.
# - ARV (Antiretroviral) shipments show higher median values with a wider range, indicating large variance in shipment costs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - **Positive Impact:** Helps prioritize cost management in high-value product groups like ARV.
# - **Negative Growth Risk:** High variance and outliers in ARV shipments may indicate inconsistent procurement or unexpected cost spikes, requiring careful monitoring.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Let's analyze the distribution of Line Item Quantity across different Product Groups using a boxplot

plt.figure(figsize=(14,7))
sns.boxplot(data=df, x='line_item_quantity', y='product_group', palette='Set2')
plt.title('Distribution of Line Item Quantity Across Product Groups')
plt.xlabel('Line Item Quantity')
plt.ylabel('Product Group')
plt.xscale('log')  # Optional: use log scale if there are large outliers
plt.show()
# Out:
# /tmp/ipython-input-1286195962.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='line_item_quantity', y='product_group', palette='Set2')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot is ideal for visualizing the distribution of a numerical variable across categories.
#
# Here, it helps identify outliers and understand the spread of line_item_quantity for each product_group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Some product groups have extreme outliers in quantity, which may indicate bulk shipments.
# - Pediatric and adult ARV products tend to have consistent quantities compared to test kits.
# - Helps detect potential data entry errors or unusual order sizes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - ✅ Positive Impact: Identifying bulk orders or unusual quantities can optimize inventory management and shipping logistics.
# - ⚠️ Negative Insight: Outliers may indicate errors in procurement or forecasting, which could cause stock imbalance if not addressed.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='shipment_mode', order=df['shipment_mode'].value_counts().index)
plt.title('Distribution of Shipments by Shipment Mode')
plt.xlabel('Shipment Mode')
plt.ylabel('Number of Shipments')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - A bar chart is suitable for comparing the frequency of shipments by `shipment_mode`.
# - Helps visualize which shipment modes are most commonly used.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Air shipments dominate the dataset, indicating faster delivery preference.
# - Few shipments use other modes like sea or road, which may affect cost efficiency.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - ✅ Positive Impact: Understanding the dominant shipment mode can help optimize logistics and reduce delivery times.
# - ⚠️ Negative Insight: Over-reliance on air shipments may increase transportation costs; diversification could improve cost efficiency.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(12,6))
sns.scatterplot(data=df, x='line_item_quantity', y='line_item_value', hue='product_group', alpha=0.7)
plt.title('Line Item Quantity vs Line Item Value by Product Group')
plt.xlabel('Line Item Quantity')
plt.ylabel('Line Item Value (USD)')
plt.legend(title='Product Group', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Scatter plots are ideal for exploring relationships between two numerical variables (`line_item_quantity` and `line_item_value`).
# - Adding `product_group` as hue helps understand if different product types behave differently.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Generally, higher quantities tend to correspond to higher line item values.
# - Some product groups have large values even for smaller quantities, indicating higher unit prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - ✅ Positive Impact: Helps procurement and pricing teams identify high-value shipments and plan better.
# - ⚠️ Negative Insight: Some outliers with extremely high value for small quantities could indicate unusual pricing or potential errors that need investigation.

# %% [markdown]
# #### Chart - 6 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(10,8))
numerical_cols = ['unit_of_measure_(per_pack)', 'line_item_quantity', 'line_item_value',
                  'pack_price', 'unit_price', 'line_item_insurance_(usd)']
corr_matrix = df[numerical_cols].corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - I chose a Correlation Heatmap because it provides a **quick overview of relationships between all numerical variables** in the dataset.
# - It helps identify which variables are strongly positively or negatively correlated, allowing us to focus on significant relationships for further analysis or predictive modeling.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - There is a **strong positive correlation** between `line_item_quantity` and `line_item_value`, which is expected because more items sold result in higher value.
# - `pack_price` and `unit_price` are also **strongly correlated**, indicating consistent pricing per unit across packs.
# - Some variables, like `line_item_insurance_(usd)`, have **low or negligible correlation** with most other variables, suggesting they are independent and might require separate analysis.
# - Insights help in understanding which variables influence total line item value the most, which can inform **pricing strategy, inventory planning, and cost management**.

# %% [markdown]
# #### Chart - 7 - Pair Plot

# %%
# Pair Plot visualization code

# Select numerical columns for pair plot
numerical_cols = ['unit_of_measure_(per_pack)', 'line_item_quantity', 'line_item_value',
                  'pack_price', 'unit_price', 'line_item_insurance_(usd)']

# Plot pair plot
sns.pairplot(df[numerical_cols], diag_kind='kde', corner=True)
plt.suptitle('Pair Plot of Numerical Variables', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - I picked a Pair Plot because it allows us to **visually explore pairwise relationships** between all numerical variables.
# - It helps detect patterns, correlations, and potential outliers in the dataset simultaneously.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - `line_item_quantity` and `line_item_value` show a **strong positive relationship**, confirming higher quantities result in higher values.
# - `pack_price` and `unit_price` are tightly clustered, indicating **consistent pricing patterns**.
# - Some variables like `line_item_insurance_(usd)` have **weak correlations** with other variables, showing independent behavior.
# - Pair plots also highlight potential **outliers**, which may require further investigation for data quality or special cases.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# - **Optimize Inventory and Shipment Planning:** Analyze historical delivery patterns, vendor performance, and shipment modes to ensure timely deliveries and reduce stockouts or overstock situations.
#
# - **Vendor Performance Monitoring:** Use insights from delivery delays, shipment modes, and vendor-specific data to identify underperforming vendors and negotiate better terms or switch to reliable vendors.
#
# - **Cost Management:** Monitor high-value items, freight costs, and insurance charges to identify opportunities to reduce total procurement and logistics expenses.
#
# - **Product & Country-Level Strategy:** Identify which products or countries frequently face delays or high costs. Implement targeted strategies to improve delivery efficiency and reduce bottlenecks.
#
# - **Data-Driven Decision Making:** Continuously track KPIs such as Line Item Value, Quantity, and Delivery Time. Use dashboards and predictive analytics to make informed decisions on procurement, shipments, and pricing.
#
# - **Business Impact:** These measures will help the client reduce operational costs, improve delivery timelines, enhance vendor reliability, and ultimately increase customer satisfaction and profitability.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# - The exploratory data analysis (EDA) of the SCMS Delivery History Dataset provided a thorough understanding of the delivery operations, product distribution, and vendor performance across multiple countries. The dataset consisted of 10,324 records and 33 columns, covering key information such as shipment details, product groups, quantities, costs, and delivery timelines. Through systematic data cleaning, standardization, and type conversions, the dataset was made ready for in-depth analysis, ensuring accurate and consistent results.
#
# - During data wrangling, we addressed missing values in critical columns such as 'Shipment Mode', 'Dosage', and 'Line Item Insurance (USD)', which helped reduce potential biases in the analysis. Column names were standardized to lowercase with underscores for easier handling in code, and date columns were converted to proper datetime formats to facilitate time-based analyses.
#
# - Univariate analysis highlighted the distribution of key numerical variables, including line item quantities, unit prices, and total line item values, identifying outliers and extreme values that could impact supply chain and financial planning. Categorical variables such as 'Country', 'Managed By', and 'Vendor' revealed trends in regional shipment volumes and vendor contributions, providing insights into global distribution strategies.
#
# - Bivariate and multivariate analyses, including bar charts, box plots, correlation heatmaps, and pair plots, helped uncover relationships between variables. For instance, correlations between 'Line Item Value' and 'Unit Price' or 'Pack Price' highlighted how product costs influence overall shipment value. Boxplots and distribution charts identified variances across product groups and regions, indicating potential areas for operational optimization.
#
# - Key insights from the analysis include:
#   1. Certain countries, such as Côte d'Ivoire, Vietnam, and Nigeria, consistently receive higher shipment volumes, which may require focused logistics and inventory management strategies.
#   2. Variations in freight and insurance costs suggest that cost efficiency could be improved by negotiating better terms with vendors or optimizing shipment methods.
#   3. Outliers in line item values and quantities highlight opportunities for better forecasting and demand planning to reduce overstocking or understocking.
#   4. Relationships between dosage, form, and shipment size can inform packaging and transportation decisions to minimize risks and costs.
#
# - Based on these insights, several recommendations can help achieve the business objectives:
#   1. Implement data-driven supply chain optimization strategies to reduce delays and costs.
#   2. Regularly monitor vendor performance and shipment efficiency to ensure timely deliveries.
#   3. Optimize inventory planning based on historical demand patterns and shipment trends.
#   4. Focus on high-volume countries and products to improve resource allocation and reduce logistical risks.
#   5. Use predictive analytics for future demand forecasting, cost optimization, and strategic planning.
#
# - Overall, this analysis provides a strong foundation for informed decision-making. The insights gained can positively impact business performance by improving operational efficiency, reducing costs, and enhancing supply chain reliability. It also highlights areas where interventions are necessary to avoid negative growth or inefficiencies, ultimately supporting the client in achieving their strategic objectives.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
